# %%
import pandas

# %%
anz = pandas.read_cvs('../data/gapminder_gdp_oceania.csv', index_col='country')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-9f2bf8ce9eef> in <module>()
# ----> 1 anz = pandas.read_cvs('../data/gapminder_gdp_oceania.csv', index_col='country')
#
# AttributeError: module 'pandas' has no attribute 'read_cvs'

# %%
anz = pandas.read_csv('../data/gapminder_gdp_oceania.csv', index_col='country')

# %%
europe = pandas.read_csv('../data/gapminder_gdp_europe.csv', index_col='country')

# %%
americas = pandas.read_csv('../data/gapminder_gdp_americas.csv', index_col='country')

# %%
africa = pandas.read_csv('../data/gapminder_gdp_africa.csv', index_col='country')

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
anz.plot()

# %%
anz.T.plot()

# %%
anz.columns
# Out:
# Index(['gdpPercap_1952', 'gdpPercap_1957', 'gdpPercap_1962', 'gdpPercap_1967',
#        'gdpPercap_1972', 'gdpPercap_1977', 'gdpPercap_1982', 'gdpPercap_1987',
#        'gdpPercap_1992', 'gdpPercap_1997', 'gdpPercap_2002', 'gdpPercap_2007'],
#       dtype='object')

# %%
europe.columns
# Out:
# Index(['gdpPercap_1952', 'gdpPercap_1957', 'gdpPercap_1962', 'gdpPercap_1967',
#        'gdpPercap_1972', 'gdpPercap_1977', 'gdpPercap_1982', 'gdpPercap_1987',
#        'gdpPercap_1992', 'gdpPercap_1997', 'gdpPercap_2002', 'gdpPercap_2007'],
#       dtype='object')

# %%
years = anz.columns.str.strip('gdpPercarp_')

# %%
anz.columns = years
anz.columns
# Out:
# Index(['1952', '1957', '1962', '1967', '1972', '1977', '1982', '1987', '1992',
#        '1997', '2002', '2007'],
#       dtype='object')

# %%
anz.columns
# Out:
# Index(['1952', '1957', '1962', '1967', '1972', '1977', '1982', '1987', '1992',
#        '1997', '2002', '2007'],
#       dtype='object')

# %%
anz.T.plot()

# %%
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %%
years = europe.columns.str.strip('gdpPercarp_')
europe.columns = years
plt.style.use('ggplot')
europe.plot(kind = 'box')

# %%
gdp_i = europe.loc[('Italy', 'Ireland', 'Iceland'),]
gdp_i
# Out:
#                 1952         1957          1962          1967          1972  \
# country
# Italy    4931.404155  6248.656232   8243.582340  10022.401310  12269.273780
# Ireland  5210.280328  5599.077872   6631.597314   7655.568963   9530.772896
# Iceland  7267.688428  9244.001412  10350.159060  13319.895680  15798.063620
#
#                 1977         1982         1987         1992         1997  \
# country
# Italy    14255.98475  16537.48350  19207.23482  22013.64486  24675.02446
# Ireland  11150.98113  12618.32141  13872.86652  17558.81555  24521.94713
# Iceland  19654.96247  23269.60750  26923.20628  25144.39201  28061.09966
#
#                 2002         2007
# country
# Italy    27968.09817  28569.71970
# Ireland  34077.04939  40675.99635
# Iceland  31163.20196  36180.78919

# %%
gdp_i.iloc[0]
# Out:
# 1952     4931.404155
# 1957     6248.656232
# 1962     8243.582340
# 1967    10022.401310
# 1972    12269.273780
# 1977    14255.984750
# 1982    16537.483500
# 1987    19207.234820
# 1992    22013.644860
# 1997    24675.024460
# 2002    27968.098170
# 2007    28569.719700
# Name: Italy, dtype: float64

# %%
plt.style.use('default')
plt.plot(years, gdp_i.iloc[0], 'g--', label='Italy')
plt.plot(years, gdp_i.iloc[1], 'b--', label='Ireland')
plt.plot(years, gdp_i.iloc[2], 'y--', label='Iceland')
plt.legend(loc='best')
plt.xlabel('years')
plt.ylabel('Gdp per Cap')
plt.title('GDP')
plt.savefig('../plots/GDP_i_countries.png')
